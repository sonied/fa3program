# %% [markdown]
# <a href="https://colab.research.google.com/github/sonied/fa3program/blob/main/fa3program!!!!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = (input("Enter your name"))
age = (input("Enter your age"))
course = (input("Enter your course"))
print("Name:", name)
print("Age:", age)
print("Course:", course)
# Out:
# Enter your namesonia
# Enter your age5
# Enter your courselaw
# Name: sonia
# Age: 5
# Course: law

# %%
score = int(input("Enter your score"))
if score >= 75:
         print("You have passed.")
else:
         print("You have failed.")
# Out:
# Enter your score70
# You have failed.

# %%
name = (input("Enter your name"))
score = int(input("Enter your score"))
if score >= 90:
  print("Name:", name)
  print("Your grade is A.")
elif score >= 80 and score <= 89:
  print("Name:", name)
  print("Your grade is B.")
elif score >=70 and score <= 79:
  print("Name:", name)
  print("Your grade is C.")
elif score <= 70:
  print("Name:", name)
  print("Your grade is F.")
# Out:
# Enter your namesonia
# Enter your score69
# Name: sonia
# Your grade is F.
